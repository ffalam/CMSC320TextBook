# %% [markdown]
# # The Four Pillars of Describing Data
#
# The four questions every Data Scientist should ask when we summarize a dataset (usually describe it along four dimensions):
#
# - Where is the **center** (location)?
#
# - How **spread** out is it?
#
# - What **shape** does it have?
#
# - How do variables **move together**?
#
# These four ideas form the **backbone** of descriptive or summary statistics.
